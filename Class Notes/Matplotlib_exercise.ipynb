# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mart = pd.read_excel('/content/supermarket_sales_data.xlsx')
mart

# %%
mart.head(10)
# Out:
#     Invoice ID       Date      Time       City Customer type  Gender  \
# 0  750-67-8428 2019-05-01  13:08:00     Yangon        Member  Female
# 1  226-31-3081 2019-08-03  10:29:00  Naypyitaw        Normal  Female
# 2  631-41-3108 2019-03-03  13:23:00     Yangon        Normal    Male
# 3  123-19-1176 2019-01-27  20:33:00     Yangon        Member    Male
# 4  373-73-7910 2019-08-02  10:37:00     Yangon        Normal    Male
# 5  699-14-3026 2019-03-25  18:30:00  Naypyitaw        Normal    Male
# 6  355-53-5943 2019-02-25  14:36:00     Yangon        Member  Female
# 7  315-22-5665 2019-02-24  11:38:00  Naypyitaw        Normal  Female
# 8  665-32-9167 2019-10-01  17:15:00     Yangon        Member  Female
# 9  692-92-5582 2019-02-20  13:27:00   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity     Total      Payment  \
# 0       Health and beauty       74.69         7  548.9715      Ewallet
# ...

# %%
# **3.Create a basic COUNTPLOT to get number of transaction for each of the product line and change the figure size**

plt.figure(figsize=(15,5))
sns.countplot(x='Product line', data=mart)
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
# **4.Make it horizontal bar plot**

sns.countplot(y ='Product line', data=mart)
# Out:
# <Axes: xlabel='count', ylabel='Product line'>

# %%
# **5.Add hue to get the count on two categories i.e. Product line and Gender**

plt.figure(figsize=(15,5))
sns.countplot(x='Product line', hue='Gender', data=mart)
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
# **6.Using different color palette**

plt.figure(figsize=(15,5))

sns.countplot(x="Product line",hue="Gender",data=mart,palette='PuBuGn_r')
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
# **7.Change Style using facecolor, linewidth and edge color**

plt.figure(figsize=(15,5))

sns.countplot(x='Product line',data=mart
             ,facecolor = (1,1,1,1)
             ,linewidth=5
             ,edgecolor=sns.color_palette('dark',3))
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %% [markdown]
# # **Barplot**

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
mart = pd.read_excel("/content/supermarket_sales_data.xlsx")
mart.head()
# Out:
#     Invoice ID       Date      Time       City Customer type  Gender  \
# 0  750-67-8428 2019-05-01  13:08:00     Yangon        Member  Female
# 1  226-31-3081 2019-08-03  10:29:00  Naypyitaw        Normal  Female
# 2  631-41-3108 2019-03-03  13:23:00     Yangon        Normal    Male
# 3  123-19-1176 2019-01-27  20:33:00     Yangon        Member    Male
# 4  373-73-7910 2019-08-02  10:37:00     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity     Total      Payment  \
# 0       Health and beauty       74.69         7  548.9715      Ewallet
# 1  Electronic accessories       15.28         5   80.2200         Cash
# 2      Home and lifestyle       46.33         7  340.5255  Credit card
# 3       Health and beauty       58.22         8  489.0480      Ewallet
# 4       Sports and travel       86.31         7  634.3785      Ewallet
#
#      cogs  gross margin percentage  gross income  Rating
# 0  522.83                 4.761905       26.1415     9.1
# ...

# %%
#**Create a basic BARPLOT**

plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',data=mart)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
#**Add HUE to the barplot**

plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',hue='Gender',data=mart)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
#**Make the barplot HORIZONTAL**

plt.figure(figsize=(15,5))

sns.barplot(x='Total',y='Product line',data=mart)
# Out:
# <Axes: xlabel='Total', ylabel='Product line'>

# %%
#**plot the bar in given order**

plt.figure(figsize=(15,5))

sns.barplot(x='Product line',
            y='Total',
            hue='Gender',
            data=mart,
            order=['Electronic accessories', 'Fashion accessories','Food and beverages', 'Health and beauty', 'Home and lifestyle','Sports and travel'],
            hue_order=['Male','Female'])

x=mart['Product line'].sort_values()
x.unique()

plt.show()

# %%
#**Add CAP on given Error Bar**

plt.figure(figsize=(15,5))

sns.barplot(x='Product line',y='Total',hue='Gender',data=mart,order=['Electronic accessories', 'Fashion accessories','Food and beverages', 'Health and beauty', 'Home and lifestyle','Sports and travel']
           ,hue_order=['Male','Female']
           ,capsize=0.2)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>
