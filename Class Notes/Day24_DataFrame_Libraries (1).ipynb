# %% [markdown]
# # **Sept 1, 2023**

# %% [markdown]
# ## **Pandas DataFrame**

# %%
import numpy as np
import pandas as pd

# %%
lang = ['C','C++','Java','Python']
df2 = pd.DataFrame(lang)
df2
# Out:
#         0
# 0       C
# 1     C++
# 2    Java
# 3  Python

# %%
rating = [4,3,2,1]
df2[1] = rating
df2
# Out:
#         0  1
# 0       C  4
# 1     C++  3
# 2    Java  2
# 3  Python  1

# %%
df2.columns = ['language', 'rating']
df2
# Out:
#   language  rating
# 0        C       4
# 1      C++       3
# 2     Java       2
# 3   Python       1

# %%
lst1 = [10,20,30,40,50,60]
df1 = pd.DataFrame(lst1)
print(df1)
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50
# 5  60

# %%
# Create Dataframe from Dictionary
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df2 = pd.DataFrame(data)
df3 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b'])
df4 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b' ,'c'])
df5 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b' ,'c' , 'd'])

# %%
print(df2)
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
print(df3)
# Out:
#       a   b
# row1  1   2
# row2  5  10

# %%
print(df4)
# Out:
#       a   b     c
# row1  1   2   NaN
# row2  5  10  20.0

# %%
print(df5)
# Out:
#       a   b     c   d
# row1  1   2   NaN NaN
# row2  5  10  20.0 NaN

# %% [markdown]
# Dataframe of Random Numbers with Date Indices

# %%
dates = pd.date_range(start='01-Aug-2023', end='31-Aug-2023')

# %%
print(dates)
# Out:
# DatetimeIndex(['2023-08-01', '2023-08-02', '2023-08-03', '2023-08-04',
#                '2023-08-05', '2023-08-06', '2023-08-07', '2023-08-08',
#                '2023-08-09', '2023-08-10', '2023-08-11', '2023-08-12',
#                '2023-08-13', '2023-08-14', '2023-08-15', '2023-08-16',
#                '2023-08-17', '2023-08-18', '2023-08-19', '2023-08-20',
#                '2023-08-21', '2023-08-22', '2023-08-23', '2023-08-24',
#                '2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range('today', periods=7)

# %%
print(dates)
# Out:
# DatetimeIndex(['2023-09-07 00:11:09.516687', '2023-09-08 00:11:09.516687',
#                '2023-09-09 00:11:09.516687', '2023-09-10 00:11:09.516687',
#                '2023-09-11 00:11:09.516687', '2023-09-12 00:11:09.516687',
#                '2023-09-13 00:11:09.516687'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range('2023-08-25', periods=7)

# %%
print(dates)
# Out:
# DatetimeIndex(['2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
M = np.random.random((7,7))
print(M)
# Out:
# [[0.60245099 0.817622   0.68985506 0.92382387 0.73842163 0.98809437
#   0.15722694]
#  [0.76338147 0.76640141 0.34101641 0.51243992 0.86415792 0.05703497
#   0.65985629]
#  [0.27094466 0.88401953 0.06911653 0.49941129 0.10226306 0.28575174
#   0.62573213]
#  [0.3159078  0.39428099 0.83073723 0.83790884 0.08404616 0.66787529
#   0.82199302]
#  [0.70553171 0.57796471 0.45995659 0.51934867 0.63422591 0.89873032
#   0.07877085]
#  [0.00576589 0.53211721 0.91050169 0.85624402 0.18350206 0.10848139
#   0.60927721]
#  [0.65295453 0.350664   0.1864143  0.70219996 0.56846773 0.01041741
#   0.63478509]]

# %%
df = pd.DataFrame(M, index=dates)
df
# Out:
#                    0         1         2         3         4         5  \
# 2023-08-25  0.602451  0.817622  0.689855  0.923824  0.738422  0.988094
# 2023-08-26  0.763381  0.766401  0.341016  0.512440  0.864158  0.057035
# 2023-08-27  0.270945  0.884020  0.069117  0.499411  0.102263  0.285752

# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-31  0.652955  0.350664  0.186414  0.702200  0.568468  0.010417
# 2023-08-30  0.005766  0.532117  0.910502  0.856244  0.183502  0.108481
# 2023-08-29  0.705532  0.577965  0.459957  0.519349  0.634226  0.898730
# 2023-08-28  0.315908  0.394281  0.830737  0.837909  0.084046  0.667875
# 2023-08-27  0.270945  0.884020  0.069117  0.499411  0.102263  0.285752
# 2023-08-26  0.763381  0.766401  0.341016  0.512440  0.864158  0.057035
# 2023-08-25  0.602451  0.817622  0.689855  0.923824  0.738422  0.988094
#
#                   C7
# 2023-08-31  0.634785
# 2023-08-30  0.609277
# 2023-08-29  0.078771
# 2023-08-28  0.821993
# 2023-08-27  0.625732
# 2023-08-26  0.659856
# 2023-08-25  0.157227

# %%
df.loc['2023-08-31']
# Out:
# C1    0.652955
# C2    0.350664
# C3    0.186414
# C4    0.702200
# C5    0.568468
# C6    0.010417
# C7    0.634785
# Name: 2023-08-31 00:00:00, dtype: float64

# %%
df.loc['2023-08-29':'2023-08-31']
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-29  0.705532  0.577965  0.459957  0.519349  0.634226  0.898730
# 2023-08-30  0.005766  0.532117  0.910502  0.856244  0.183502  0.108481
# 2023-08-31  0.652955  0.350664  0.186414  0.702200  0.568468  0.010417
#
#                   C7
# 2023-08-29  0.078771
# 2023-08-30  0.609277
# 2023-08-31  0.634785

# %%
df['C1']
# Out:
# 2023-08-25    0.602451
# 2023-08-26    0.763381
# 2023-08-27    0.270945
# 2023-08-28    0.315908
# 2023-08-29    0.705532
# 2023-08-30    0.005766
# 2023-08-31    0.652955
# Freq: D, Name: C1, dtype: float64

# %%
dict1 = {'A': pd.Series([1,2,3,4], index = ['a','b','c','d']),
         'B': pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
         }
df1 = pd.DataFrame(dict1)
df1
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4
# e  NaN  5

# %%
del df1['B']
df1
# Out:
#      A
# a  1.0
# b  2.0
# c  3.0
# d  4.0
# e  NaN

# %%
dict = {'A' : pd.Series([1, 2, 3,11], index=['a', 'b', 'c','d']),
'B' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}
df12 = pd.DataFrame(dict)
df12
# Out:
#     A  B
# a   1  1
# b   2  2
# c   3  3
# d  11  4

# %%
df12.drop(['A'], axis=1) # axis=0 => rows,  axis=1 => columns
df12
# Out:
#     A  B
# a   1  1
# b   2  2
# c   3  3
# d  11  4

# %%
df12.drop(['A'], axis=1, inplace=True) # axis=0 => rows,  axis=1 => columns
df12
# Out:
#    B
# a  1
# b  2
# c  3
# d  4

# %%
df12.drop(['c'], axis=0, inplace=True) # axis=0 => rows,  axis=1 => columns
df12
# Out:
#    B
# a  1
# b  2
# d  4

# %%
col1 = np.linspace(10, 100, 30)
col2 = np.random.randint(10,100,30)
df10 = pd.DataFrame({"C1" : col1 , "C2" :col2})
df10
# Out:
#             C1  C2
# 0    10.000000  20
# 1    13.103448  68
# 2    16.206897  35
# 3    19.310345  59
# 4    22.413793  25
# 5    25.517241  41
# 6    28.620690  34
# 7    31.724138  79
# 8    34.827586  15
# 9    37.931034  56
# 10   41.034483  81
# 11   44.137931  51
# 12   47.241379  70
# 13   50.344828  42
# 14   53.448276  46
# 15   56.551724  76
# 16   59.655172  92
# 17   62.758621  67
# 18   65.862069  44
# 19   68.965517  77
# 20   72.068966  58
# 21   75.172414  31
# 22   78.275862  39
# 23   81.379310  82
# 24   84.482759  51
# 25   87.586207  49
# 26   90.689655  98
# 27   93.793103  41
# 28   96.896552  89
# 29  100.000000  21

# %%
df10.iloc[10:15]
# Out:
#            C1  C2
# 10  41.034483  81
# 11  44.137931  51
# 12  47.241379  70
# 13  50.344828  42
# 14  53.448276  46

# %%
df10.loc[10]
# Out:
# C1    41.034483
# C2    81.000000
# Name: 10, dtype: float64

# %%
df10.iloc[10:15, 0]
# Out:
# 10    41.034483
# 11    44.137931
# 12    47.241379
# 13    50.344828
# 14    53.448276
# Name: C1, dtype: float64

# %%
df10.loc[10]
# Out:
# C1    41.034483
# C2    81.000000
# Name: 10, dtype: float64

# %%
df10.loc[10:15, 'C1']
# Out:
# 10    41.034483
# 11    44.137931
# 12    47.241379
# 13    50.344828
# 14    53.448276
# 15    56.551724
# Name: C1, dtype: float64

# %%
df10.iloc[10:15, 0]
# Out:
# 10    41.034483
# 11    44.137931
# 12    47.241379
# 13    50.344828
# 14    53.448276
# Name: C1, dtype: float64

# %%
df10.loc[10:,'C1':]
# Out:
#             C1  C2
# 10   41.034483  81
# 11   44.137931  51
# 12   47.241379  70
# 13   50.344828  42
# 14   53.448276  46
# 15   56.551724  76
# 16   59.655172  92
# 17   62.758621  67
# 18   65.862069  44
# 19   68.965517  77
# 20   72.068966  58
# 21   75.172414  31
# 22   78.275862  39
# 23   81.379310  82
# 24   84.482759  51
# 25   87.586207  49
# 26   90.689655  98
# 27   93.793103  41
# 28   96.896552  89
# 29  100.000000  21

# %%
df10.iloc[10:, 0:]
# Out:
#             C1  C2
# 10   41.034483  81
# 11   44.137931  51
# 12   47.241379  70
# 13   50.344828  42
# 14   53.448276  46
# 15   56.551724  76
# 16   59.655172  92
# 17   62.758621  67
# 18   65.862069  44
# 19   68.965517  77
# 20   72.068966  58
# 21   75.172414  31
# 22   78.275862  39
# 23   81.379310  82
# 24   84.482759  51
# 25   87.586207  49
# 26   90.689655  98
# 27   93.793103  41
# 28   96.896552  89
# 29  100.000000  21

# %% [markdown]
# loc = location   df10.loc[10:,'c1']
#
#
# iloc = index     df10.loc[10:, 0:]

# %%
df.columns = ['C1','C2','C3','C4','C5','C6','C7']
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.602451  0.817622  0.689855  0.923824  0.738422  0.988094
# 2023-08-26  0.763381  0.766401  0.341016  0.512440  0.864158  0.057035
# 2023-08-27  0.270945  0.884020  0.069117  0.499411  0.102263  0.285752
# 2023-08-28  0.315908  0.394281  0.830737  0.837909  0.084046  0.667875
# 2023-08-29  0.705532  0.577965  0.459957  0.519349  0.634226  0.898730
# 2023-08-30  0.005766  0.532117  0.910502  0.856244  0.183502  0.108481
# 2023-08-31  0.652955  0.350664  0.186414  0.702200  0.568468  0.010417
#
#                   C7
# 2023-08-25  0.157227
# 2023-08-26  0.659856
# 2023-08-27  0.625732
# 2023-08-28  0.821993
# 2023-08-29  0.078771
# 2023-08-30  0.609277
# 2023-08-31  0.634785

# %%
df.loc['2023-08-25':'2023-08-25','C1':'C1']
# Out:
#                   C1
# 2023-08-25  0.602451

# %%
df.loc['2023-08-26':'2023-08-26','C2':'C2']
# Out:
#                   C2
# 2023-08-26  0.766401

# %%
df.loc['2023-08-27':'2023-08-27','C3':'C3']
# Out:
#                   C3
# 2023-08-27  0.069117

# %%
df.loc['2023-08-28':'2023-08-28','C4':'C4']
# Out:
#                   C4
# 2023-08-28  0.837909

# %%
df.loc['2023-08-29':'2023-08-29','C5':'C5']
# Out:
#                   C5
# 2023-08-29  0.634226

# %%
df.loc['2023-08-30':'2023-08-30','C6':'C6']
# Out:
#                   C6
# 2023-08-30  0.108481

# %%
df.loc['2023-08-31':'2023-08-31','C7':'C7']
# Out:
#                   C7
# 2023-08-31  0.634785

# %%
df.columns = ['C1','C2','C3','C4','C5','C6','C7']
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0
# 2023-08-25  0.602451  0.817622  0.689855  0.923824
# 2023-08-26  0.763381  0.766401  0.341016  0.512440
# 2023-08-27  0.270945  0.884020  0.069117  0.499411
# 2023-08-28  0.315908  0.394281  0.830737  0.837909
# 2023-08-29  0.705532  0.577965  0.459957  0.519349
# 2023-08-30  0.005766  0.532117  0.910502  0.856244
# 2023-08-31  0.652955  0.350664  0.186414  0.702200

# %%
df.iloc[:,:]
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.602451  0.817622  0.689855  0.923824  0.738422  0.988094
# 2023-08-26  0.763381  0.766401  0.341016  0.512440  0.864158  0.057035
# 2023-08-27  0.270945  0.884020  0.069117  0.499411  0.102263  0.285752
# 2023-08-28  0.315908  0.394281  0.830737  0.837909  0.084046  0.667875
# 2023-08-29  0.705532  0.577965  0.459957  0.519349  0.634226  0.898730
# 2023-08-30  0.005766  0.532117  0.910502  0.856244  0.183502  0.108481
# 2023-08-31  0.652955  0.350664  0.186414  0.702200  0.568468  0.010417
#
#                   C7
# 2023-08-25  0.157227
# 2023-08-26  0.659856
# 2023-08-27  0.625732
# 2023-08-28  0.821993
# 2023-08-29  0.078771
# 2023-08-30  0.609277
# 2023-08-31  0.634785

# %%
df.iloc[6:,0:1]      #index starts from 0 in python datas.
                     # and value return is (n-1)
# Out:
#                   C1
# 2023-08-31  0.652955

# %%
df.iloc[5:6,1:2]     #[5:6, : ] means (6-1=5), value starts from 5 end upto 6, which is 5
# Out:
#                   C2
# 2023-08-30  0.532117

# %%
df.iloc[4:5,2:3]
# Out:
#                   C3
# 2023-08-29  0.459957

# %%
df.iloc[3:4,3:4]
# Out:
#                   C4
# 2023-08-28  0.837909

# %%
df.iloc[2:3,4:5]
# Out:
#                   C5
# 2023-08-27  0.102263

# %%
df.iloc[1:2,5:6]
# Out:
#                   C6
# 2023-08-26  0.057035

# %%
df.iloc[0:1,6:]
# Out:
#                   C7
# 2023-08-25  0.157227

# %%
df

# %%
path = '/content/Churn_Modelling.csv'
df_Churn_Modelling = pd.read_csv(path)
df_Churn_Modelling

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_Churn_Modelling.iloc[9999:,:1]

# %%
df_Churn_Modelling.iloc[9998:9999,1:2]

# %%
df_Churn_Modelling.iloc[:1,2:3]

# %%
df_Churn_Modelling.iloc[9996:9997,:]

# %%
df_Churn_Modelling.iloc[9996:9997,:7]

# %%
df_Churn_Modelling.iloc[9995:,:7]

# %%
df_Churn_Modelling.info()

# %%
df_Churn_Modelling.describe()

# %%
df_Churn_Modelling.describe

# %%
df_Churn_Modelling.describe(include='all')

# %%
df_Churn_Modelling.dtypes

# %%
df_Churn_Modelling.size

# %%
df_Churn_Modelling.columns

# %%
df_Churn_Modelling.ndim

# %%
df_Churn_Modelling.shape           #shape = rows and columns

# %%
# EDA = Exploartory Data Analysis

# %%
df_Churn_Modelling.isnull()

# %%
df_Churn_Modelling.isnull().sum()

# %%
df_Churn_Modelling.count()

# %%
# df_Churn_Modelling.describe()         () means functions
# df_Churn_Modelling.describe           no brackets means attributes

# %%
df_Churn_Modelling.CreditScore

# %%
df_Churn_Modelling['CreditScore']

# %%
df_Churn_Modelling.CreditScore, df_Churn_Modelling.Surname

# %%
df_Churn_Modelling[['Surname','CreditScore']]

# %%
df_Churn_Modelling[['CustomerId','Surname','CreditScore','Age']]

# %%
df_Churn_Modelling

# %% [markdown]
# # **Data Selection based on condition**

# %%
df_Churn_Modelling[df_Churn_Modelling.Gender == 'Male']

# %%
df_Churn_Modelling[(df_Churn_Modelling.Gender == 'Male') & (df_Churn_Modelling.Age >= 45)]

# %%
df_Churn_Modelling[(df_Churn_Modelling.Gender == 'Male') & (df_Churn_Modelling.Age >= 45) & (df_Churn_Modelling.Balance>=50000)]

# %%
df_Churn_Modelling[(df_Churn_Modelling.Age >= 45) & (df_Churn_Modelling.Balance>=50000) & (df_Churn_Modelling.EstimatedSalary>=75000)]

# %%
df_Churn_Modelling.Surname.unique()
# Out:
# array(['Hargrave', 'Hill', 'Onio', ..., 'Kashiwagi', 'Aldridge',
#        'Burbidge'], dtype=object)

# %% [markdown]
# # ===============================================================

# %% [markdown]
# # **Day 23, Wed, Sept 6**

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
df_chipotle = pd.read_csv(url, sep='\t')
df_chipotle

# %%
df_chipotle[df_chipotle.item_name=='Chips and Fresh Tomato Salsa']

# %%
df_chipotle.iloc[25:26,:]

# %%
# remove dollar $$$ sign and convert it to float

for value in df_chipotle.item_price:
  print(value[1:-1])

prices = [float(value[1:-1]) for value in df_chipotle.item_price]

df_chipotle.item_price = prices

# %%
df_chipotle

# %%
df_chipotle[df_chipotle.item_price < 10]

# %%
df_chipotle.item_name.unique()

# %%
df_chipotle.choice_description.unique()

# %%
df_chipotle[df_chipotle.choice_description.isin(['[Apple]'])]

# %%
df_chipotle[df_chipotle.item_name.isin(['Chicken Bowl','Chicken Burrito'])]

# %%
df_chipotle[df_chipotle.item_name=='Chips and Fresh Tomato Salsa']

# %% [markdown]
# # ===============================================================

# %%
import numpy as np
import pandas as pd

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
df_users = pd.read_csv(url, sep='|')
df_users

# %%
df_users.columns

# %%
df_users.occupation.unique()

# %%
df_users.head()

# %%
df_users.tail()

# %%
df_users.groupby('occupation').sum()

# %%
df_users.groupby('occupation').count()

# %%
df_users.groupby('occupation').age.count()

# %%
df_users.query("occupation == 'homemaker'").groupby(['occupation', 'gender']).count()

# %%
df_homemaker = df_users[df_users['occupation'] == 'homemaker'].groupby('gender').count()
df_homemaker

# %%
df_users.groupby('occupation').age.agg(['min', 'max'])

# %%
df_users

# %%
df_users.query("occupation == 'technician'")

# %%
df_users.groupby("occupation == 'technician'").male

# %% [markdown]
# ## **DataSet Sept 7, 2023**

# %%
import numpy as np
import pandas as pd

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'],
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}

# %%
regiment = pd.DataFrame(raw_data, columns = raw_data.keys())

# %%
regiment

# %%
regiment.groupby('regiment').company.count()

# %%
regiment.query("regiment == 'Nighthawks'")

# %%
regiment[regiment['regiment'].isin (['Nighthawks'])].groupby('regiment').count()

# %% [markdown]
# ## ============================================================

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'

# %%
df_uscrime = pd.read_csv(url)
df_uscrime

# %%
df_uscrime.info()

# %%
df_uscrime.shape

# %%
df_uscrime.Burglary

# %%
df_uscrime[df_uscrime.Year == 2014]

# %%
df_uscrime.loc[54:54, :] #2014

# %%
df_uscrime.loc[50:54, 'Burglary':'Burglary']  #2010 to 2014

# %%
df_uscrime[['Year','Burglary']].iloc[50:, :] #2010 to 2014

# %%
df_uscrime[['Year','Burglary']]

# %% [markdown]
# # ============================================================

# %%
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %%
data1 = pd.DataFrame(raw_data_1, columns = ['subject_id', 'first_name', 'last_name'])
data2 = pd.DataFrame(raw_data_2, columns = ['subject_id', 'first_name', 'last_name'])
data3 = pd.DataFrame(raw_data_3, columns = ['subject_id','test_id'])

# %%
new_data = pd.concat([data1, data2])
new_data
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
new_data = pd.concat([data1, data2], axis=1)
new_data
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan
