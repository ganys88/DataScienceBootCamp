# %% [markdown]
# https://www.youtube.com/watch?v=ZyhVh-qRZPA&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS

# %%
# dataframe (df) is basically datas in 'rows' and 'column

# %%
import pandas as pd

# %%
df_Churn_Modelling = pd.read_csv('/content/Churn_Modelling.csv')    #this process is how we import dataframe

# %%
df_Churn_Modelling # print the dataframe
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_Churn_Modelling[['RowNumber','Surname','CreditScore','Geography','Gender','Age','EstimatedSalary']]
# Out:
#       RowNumber    Surname  CreditScore Geography  Gender  Age  \
# 0             1   Hargrave          619    France  Female   42
# 1             2       Hill          608     Spain  Female   41
# 2             3       Onio          502    France  Female   42
# 3             4       Boni          699    France  Female   39
# 4             5   Mitchell          850     Spain  Female   43
# ...         ...        ...          ...       ...     ...  ...
# 9995       9996   Obijiaku          771    France    Male   39
# 9996       9997  Johnstone          516    France    Male   35
# 9997       9998        Liu          709    France  Female   36
# 9998       9999  Sabbatini          772   Germany    Male   42
# 9999      10000     Walker          792    France  Female   28
#
#       EstimatedSalary
# 0           101348.88
# 1           112542.58
# 2           113931.57
# 3            93826.63
# 4            79084.10
# ...               ...
# 9995         96270.64
# ...

# %%
country_grp = df_Churn_Modelling.groupby(['Geography'])

# %%
country_grp.get_group('France')
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 8             9    15792365         He          501    France    Male   44
# ...         ...         ...        ...          ...       ...     ...  ...
# 9994       9995    15719294       Wood          800    France  Female   29
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
filt = df_Churn_Modelling['Geography'] == 'France'
df_Churn_Modelling.loc[filt]['Surname'].value_counts()

# %%
country_grp.get_group('France').value_counts().head(10)
# Out:
# RowNumber  CustomerId  Surname    CreditScore  Geography  Gender  Age  Tenure  Balance    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 1          15634602    Hargrave   619          France     Female  42   2       0.00       1              1          1               101348.88        1         1
# 6682       15736717    Ma         602          France     Male    31   7       155271.83  1              1          1               179446.31        0         1
# 6697       15587299    Board      567          France     Female  48   3       0.00       1              1          0               55362.45         0         1
# 6696       15615473    Sabbatini  646          France     Female  33   2       0.00       2              0          0               198208.00        0         1
# 6694       15665784    She        637          France     Male    27   9       128940.24  1              1          0               46786.92         0         1
# ...

# %%
df_Churn_Modelling.loc[[1000],['Surname','CreditScore']]

# %%
df_Churn_Modelling['Surname']      # ['Surname'] just gives values
# Out:
# 0        Hargrave
# 1            Hill
# 2            Onio
# 3            Boni
# 4        Mitchell
#           ...
# 9995     Obijiaku
# 9996    Johnstone
# 9997          Liu
# 9998    Sabbatini
# 9999       Walker
# Name: Surname, Length: 10000, dtype: object

# %%
df_Churn_Modelling[['Surname']]    # [['Surname']] gives values with 'dataframe' [dataframe = container]
# Out:
#         Surname
# 0      Hargrave
# 1          Hill
# 2          Onio
# 3          Boni
# 4      Mitchell
# ...         ...
# 9995   Obijiaku
# 9996  Johnstone
# 9997        Liu
# 9998  Sabbatini
# 9999     Walker
#
# [10000 rows x 1 columns]

# %%
employee = {'id':['1','2','3','4'],                                   #raw data
            'name':['Anu','Rohit','Nirusha','Ganesh'],
            'salary':['75000','80000','55000','45000'],
            'position':['Engineer','Analyst','Manager','Supervisor'],
            'age':['55','45','25','35']}

# %%
employee['name']
# Out:
# ['Anu', 'Rohit', 'Nirusha', 'Ganesh']

# %%
                                        # constructing dataframe from 'dict' including 'series'.
df_practice = pd.DataFrame(employee)    # 'DataFrame' must be in 'Captital' it can't be 'dataframe'

# %%
df_practice
# Out:
#   id     name salary    position age
# 0  1      Anu  75000    Engineer  55
# 1  2    Rohit  80000     Analyst  45
# 2  3  Nirusha  55000     Manager  25
# 3  4   Ganesh  45000  Supervisor  35

# %%
df_practice[['name']]
# Out:
#       name
# 0      Anu
# 1    Rohit
# 2  Nirusha
# 3   Ganesh

# %%
df_practice.loc[[0],['name','position']]
# Out:
#   name  position
# 0  Anu  Engineer

# %%
df_practice.iloc[[0]]
# Out:
#   id name salary  position age
# 0  1  Anu  75000  Engineer  55

# %%
df_practice.columns
# Out:
# Index(['id', 'name', 'salary', 'position', 'age'], dtype='object')

# %%
df_practice.rename(columns = {'name':'first_name'}, inplace = True)  # rename # rename # rename #rename

# %%
df_practice
# Out:
#   id first_name salary    position age
# 0  1        Anu  75000    Engineer  55
# 1  2      Rohit  80000     Analyst  45
# 2  3    Nirusha  55000     Manager  25
# 3  4     Ganesh  45000  Supervisor  35

# %%
name = 'Ganesh'
print(f'My name is {name}.')
print('My name is', name)
# Out:
# My name is Ganesh.
# My name is Ganesh

# %%
import pandas as pd

# %%
# create a CSV file (comma separated value) in notepad and save it as csv.
#then upload CSV file in files and the copy the path of the file and write
# file_name = pd.read_csv('paste copied path here')
employee_data = pd.read_csv('/content/employee_data.csv')

# %%
employee_data
# Out:
#    id     name    position  salary  age
# 0   1   Anurag    Engineer   75000   55
# 1   2    Rohit     Analyst   65000   45
# 2   3  Nirusha     Manager   55000   25
# 3   4   Ganesh  Supervisor   45000   35

# %%
def update_name(name):
  return name.upper()

# %%
employee_data['name'] = employee_data['name'].apply(update_name)
employee_data
# Out:
#    id     name    position  salary  age
# 0   1   ANURAG    Engineer   75000   55
# 1   2    ROHIT     Analyst   65000   45
# 2   3  NIRUSHA     Manager   55000   25
# 3   4   GANESH  Supervisor   45000   35

# %%
employee_data['name'] = employee_data['name'].apply(lambda x:x.lower())
employee_data
# Out:
#    id     name    position  salary  age
# 0   1   anurag    Engineer   75000   55
# 1   2    rohit     Analyst   65000   45
# 2   3  nirusha     Manager   55000   25
# 3   4   ganesh  Supervisor   45000   35

# %%
employee_data['name'].replace({'anurag':'Anurag','rohit':'Rohit','nirusha':'Nirusha','ganesh':'Ganesh'})
employee_data['name']=employee_data['name'].replace({'anurag':'Anurag','rohit':'Rohit','nirusha':'Nirusha','ganesh':'Ganesh'})

# %%
employee_data
# Out:
#    id     name    position  salary  age
# 0   1   Anurag    Engineer   75000   55
# 1   2    Rohit     Analyst   65000   45
# 2   3  Nirusha     Manager   55000   25
# 3   4   Ganesh  Supervisor   45000   35

# %%
employee_data = employee_data.append({'id':'5','name':'Blake','position':'CEO','salary':10000,'age':'35'}, ignore_index=True)
# Out:
# <ipython-input-148-667110686f74>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   employee_data = employee_data.append({'id':'5','name':'Blake','position':'CEO','salary':10000,'age':'35'}, ignore_index=True)

# %%
employee_data
# Out:
#   id     name    position  salary age
# 0  1   Anurag    Engineer   75000  55
# 1  2    Rohit     Analyst   65000  45
# 2  3  Nirusha     Manager   55000  25
# 3  4   Ganesh  Supervisor   45000  35
# 4  5    Blake    Boss-Man   10000  35
# 5  5    Blake         CEO   10000  35

# %%
employee_data.shape                        #gives rows and column
# Out:
# (5, 5)

# %%
#df.shape and len(df) gives same thing
for k in range (employee_data.shape[0]):   #prints 'k' which is row starting from 'shape[0]'
  print(k)                                 # 4 is the total number of row so 0=0,1=1,2=2,3=3 total 4 rows.
# Out:
# 0
# 1
# 2
# 3

# %%
# "w" :- this will always create a new file while writing
# "a" :- this will attach things in same file if exsists if not create a new file
# "r" :- reads the data from text file
# "wb" :- writes data in non human readble form
# "rb" :- reads data from non human readble form

# %%
# 1 need to ask user for a number

# 2 ask user for how many rows needed

# 3 number of rows is basically where iteration stops

# 4 csv should be 3 columns

# 5 1st column is like 5,5,10,15,25,40,....................

# 6 2nd column is like 5,25,625,.................. square

# 7 3rd 5,125,................. cube

# %%
import pandas as pd
num=int(input("Please enter the number you want to play with "))
rows=int(input("Please enter rows required"))


all_data=[]
for k in range(rows):
  if k==0:
    all_data.append([num,num,num])
  elif k==1:
    all_data.append([all_data[-1][0],all_data[-1][1]**2,all_data[-1][2]**3])
  elif k>1:
    last_element=all_data[-1][0]
    second_last=all_data[-2][0]
    all_data.append([last_element+second_last,all_data[-1][1]**2,all_data[-1][2]**3])

df=pd.DataFrame(all_data,columns=['Sum',"Square","Cube"])
df.to_csv("Data.csv",index=False)

# %%
df_Churn_Modelling

# %%
filt = (df_Churn_Modelling['Geography'] == 'France')
df_France = df_Churn_Modelling[filt]
df_France

# %%
df_France.to_csv('df_France_csv.csv')

# %%
df_France.to_excel('df_France_xlsx.xlsx')

# %%
import pandas as pd
num=int(input("Please enter the number you want to play with "))
rows=int(input("Please enter rows required"))


all_data=[]
for k in range(rows):
  if k==0:
    all_data.append([num,num,num])
  elif k==1:
    all_data.append([all_data[-1][0],all_data[-1][1]**2,all_data[-1][2]**3])
  elif k>1:
    last_element=all_data[-1][0]
    second_last=all_data[-2][0]
    all_data.append([last_element+second_last,all_data[-1][1]**2,all_data[-1][2]**3])

df=pd.DataFrame(all_data,columns=['Sum',"Square","Cube"])
df.to_csv("Data.csv",index=False)
# Out:
# Please enter the number you want to play with 5
# Please enter rows required3

# %%
names_list =['rohit','rohit','rohit','rohit','rohit','anurag','anurag','anurag','nirusha']

user_entered_name = 'anurag'

all_matching_names = []
for k in names_list:
  if k == user_entered_name:
    all_matching_names.append(k)

print(all_matching_names)
# Out:
# ['anurag', 'anurag', 'anurag']
